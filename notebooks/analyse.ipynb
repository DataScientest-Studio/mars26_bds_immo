# %%
import pandas as pd

ventes = pd.read_csv("../data/raw/ech_annonces_ventes_68.csv", sep=";")

ventes.head()
# Out:
#                 idannonce type_annonceur typedebien typedetransaction  etage  \
# 0  hektor-robischung-2862             pr          a                 v      0
# 1          apimo-82452515             pr          m                 v      0
# 2    immo-facile-52471952             pr          m                 v      0
# 3    immo-facile-52477215             pr          a                 v      0
# 4      ag681088-383601401             pr          m                 v      0
#
#    surface  surface_terrain  nb_pieces  prix_bien  prix_maison  ...  UU2010  \
# 0       64              NaN          3     128400          NaN  ...   68113
# 1       85           4950.0          4     189000          NaN  ...   68000
# 2      187           3182.0          9     282900          NaN  ...   68000
# 3       76              NaN          4      79000          NaN  ...   68000
# 4       90           3071.0          5     317000          NaN  ...   68000
#
# ...

# %%
ventes.head()
# Out:
#                 idannonce type_annonceur typedebien typedetransaction  etage  \
# 0  hektor-robischung-2862             pr          a                 v      0
# 1          apimo-82452515             pr          m                 v      0
# 2    immo-facile-52471952             pr          m                 v      0
# 3    immo-facile-52477215             pr          a                 v      0
# 4      ag681088-383601401             pr          m                 v      0
#
#    surface  surface_terrain  nb_pieces  prix_bien  prix_maison  ...  UU2010  \
# 0       64              NaN          3     128400          NaN  ...   68113
# 1       85           4950.0          4     189000          NaN  ...   68000
# 2      187           3182.0          9     282900          NaN  ...   68000
# 3       76              NaN          4      79000          NaN  ...   68000
# 4       90           3071.0          5     317000          NaN  ...   68000
#
# ...

# %%
ventes.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27737 entries, 0 to 27736
# Data columns (total 59 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   idannonce                27737 non-null  str
#  1   type_annonceur           27737 non-null  str
#  2   typedebien               27737 non-null  str
#  3   typedetransaction        27737 non-null  str
#  4   etage                    27737 non-null  int64
#  5   surface                  27737 non-null  int64
#  6   surface_terrain          11444 non-null  float64
#  7   nb_pieces                27737 non-null  int64
#  8   prix_bien                27737 non-null  int64
#  9   prix_maison              437 non-null    float64
#  10  prix_terrain             437 non-null    float64
#  11  mensualiteFinance        27737 non-null  int64
#  12  balcon                   27737 non-null  int64
#  13  eau                      27737 non-null  int64
# ...

# %%
ventes['prix_m2_calcule'] = ventes['prix_bien'] / ventes['surface']
ventes_clean = ventes.drop(columns=['prix_maison', 'prix_terrain'])

# %%
ventes_clean.to_csv("../data/processed/ventes_clean.csv", index=False)

# %%
import pandas as pd

# Charger le fichier depuis raw
ventes = pd.read_csv("../data/raw/ech_annonces_ventes_68.csv", sep=";")

# Créer une copie pour travailler dessus
ventes_clean = ventes.copy()

# %%
# Aperçu des premières lignes
ventes_clean.head()

# Informations sur le type des colonnes et valeurs manquantes
ventes_clean.info()

# Statistiques descriptives pour les colonnes numériques
ventes_clean.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27737 entries, 0 to 27736
# Data columns (total 59 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   idannonce                27737 non-null  str
#  1   type_annonceur           27737 non-null  str
#  2   typedebien               27737 non-null  str
#  3   typedetransaction        27737 non-null  str
#  4   etage                    27737 non-null  int64
#  5   surface                  27737 non-null  int64
#  6   surface_terrain          11444 non-null  float64
#  7   nb_pieces                27737 non-null  int64
#  8   prix_bien                27737 non-null  int64
#  9   prix_maison              437 non-null    float64
#  10  prix_terrain             437 non-null    float64
#  11  mensualiteFinance        27737 non-null  int64
#  12  balcon                   27737 non-null  int64
#  13  eau                      27737 non-null  int64
# ...

# %%
ventes.isnull().sum()
# Out:
# idannonce                      0
# type_annonceur                 0
# typedebien                     0
# typedetransaction              0
# etage                          0
# surface                        0
# surface_terrain            16293
# nb_pieces                      0
# prix_bien                      0
# prix_maison                27300
# prix_terrain               27300
# mensualiteFinance              0
# balcon                         0
# eau                            0
# bain                           0
# dpeL                           0
# dpeC                       10587
# mapCoordonneesLatitude         0
# mapCoordonneesLongitude        0
# annonce_exclusive              0
# nb_etages                  12878
# parking                    27710
# places_parking             17568
# cave                       14490
# exposition                     0
# ges_class                   8021
# annee_construction         18279
# nb_toilettes               12301
# ...
