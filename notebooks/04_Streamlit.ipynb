# %%
pip install Streamlit
# Out:
# ...
#    ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#    ------------------------------- -------- 7.3/9.2 MB 37.9 MB/s eta 0:00:01
#    ---------------------------------------  9.2/9.2 MB 38.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.2/9.2 MB 19.7 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/797.0 kB ? eta -:--:--
#    ---------------------------------------- 797.0/797.0 kB 10.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ------------------------------------- -- 10.5/11.3 MB 57.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 34.6 MB/s  0:00:00
# ...
#
#    ----------------------------------------  0/19 [websockets]
#    ----------------------------------------  0/19 [websockets]
#    ----------------------------------------  0/19 [websockets]
#    ----------------------------------------  0/19 [websockets]
# ...
